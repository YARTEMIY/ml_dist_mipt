# %% [markdown]
# # Ядра для SVM

# %% [markdown]
# **В этом задании мы попрактикуемся в написании ядер для SVM, в частности напишем rbf-ядро.**

# %%
'''
Если вы работаете в Google Colab, раскомментируйте строку ниже чтобы скачать файл `svm.py`
'''
# !wget https://raw.githubusercontent.com/evgeniishch/ml-dist-mipt/main/homeworks/hw3_svm/svm.py
# Out:
# '\nЕсли вы работаете в Google Colab, раскомментируйте строку ниже чтобы скачать файл `svm.py`\n'

# %%
import matplotlib.pyplot as plt
# use seaborn plotting defaults
import seaborn as sns; sns.set()
import numpy as np
from sklearn.metrics import accuracy_score

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for our SVM class"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 50)
    y = np.linspace(ylim[0], ylim[1], 50)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.predict(xy).reshape(X.shape)
    # plot decision boundary and margins
    CS = ax.contourf(X, Y, P, origin='lower', cmap='autumn', alpha=0.1)
    plt.colorbar(CS, ax=ax, shrink=0.8, extend='both')
    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
from sklearn.datasets import make_circles

from sklearn.svm import SVC # "Support vector classifier"

X, y = make_circles(150, factor=.1, noise=.1, random_state=42)

X_test, y_test = X[100:], y[100:]
X, y = X[:100], y[:100]

# %% [markdown]
# ### Sklearn realization:

# %%
clf = SVC(kernel='linear').fit(X, y)
pred = clf.predict(X_test)
print("Test accuracy: ", accuracy_score(y_test, pred))
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);
# Out:
# Test accuracy:  0.64

# %%
clf = SVC(kernel='rbf').fit(X, y)
pred = clf.predict(X_test)
print("Test accuracy: ", accuracy_score(y_test, pred))
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);
# Out:
# Test accuracy:  1.0

# %% [markdown]
# ## Посмотрим на нашу реализацию

# %% [markdown]
# ### Вам необходимо заполнить пропуски в файле svm.py

# %% [markdown]
# __Прмяую__ задачу оптимизации для SVM можно сформулировать как
#
# $$ \frac{1}{n} \sum_{i=1}^n \max(0, 1 - y_i (w X_i - b)) + \lambda ||w||_2 \to \min_w $$
#
# Эту задачу можно решить с помощью градиентных или суб-градиентных методов.
#
# -----
# В свою очередь __двойственная__ задача оптимизации имеет вид:
#
# $$
# \sum_{i=1}^n c_i - \frac{1}{2} \sum_{i=1}^n \sum_{j=1}^n y_i c_i (X_i \cdot X_j ) y_j c_j \to \max_{c_1,...,c_n} \\ \text{при условии} \\
# \sum_{i=1}^n c_iy_i=0 \\
# 0 \leq c_i \leq \frac{1}{2n\lambda} \forall i
# $$
#
# Где $W = \sum_{i=1}^n c_i y_i X_i$.
#
# В этой задаче квадратичного программирования мы можем сипользовать kernel trick: <br/>
# рассмотрим функцию $K(X_i, X_j) = \phi (X_i) \phi (X_j)$ и заменим скалярные произведения в нашей задаче оптимизации
#
# Мы получим
#
# $$
# \sum_{i=1}^n c_i - \frac{1}{2} \sum_{i=1}^n \sum_{j=1}^n y_i c_i K(X_i, X_j) y_j c_j \to \max_{c_1,...,c_n} \\
# \text{при условии} \\
# \sum_{i=1}^n c_iy_i=0 \\
# 0 \leq c_i \leq \frac{1}{2n\lambda} \forall i
# $$
#
# $W = \sum_{i=1}^n c_i y_i \phi(X_i)$
#
# ----
# При этом прямая задача оптимизации с ядром может быть сформулирована как (см. [Olivier Chapelle, 2006](https://www.cs.utah.edu/~piyush/teaching/svm-solving-primal.pdf)):
#
# $$f(x) = \sum_{i=1}^n \beta_i K(x_i, x)$$
#
# $$K: K_{i,j} = K(x_i, x_j)$$
#
# $$ \lambda \vec{\beta^T} K \vec{\beta} + \sum_{i=1}^n L(y_i, K_i^T \vec{\beta}) \to \min_{\vec{\beta}}$$
#
# где L это Hinge loss: $L(y_i, K_i^T \vec{\beta}) = \max(0, 1 - y_i (K_i^T \vec{\beta}))$

# %% [markdown]
# #### Ядро Radial basis function.
#
# ####  Функция ядра RBF для двух объектов x and x', представленных векторами признаков в некотором пространстве, может быть определена как:
#
# ## $K(x,x') = \exp \big{[}- \frac{||x-x'||^2}{2 \sigma^2} \big{]}.$

# %% [markdown]
# ### Проверим себя:

# %%
from svm import SVM

# %load_ext autoreload
# %autoreload 2

# %%
y[y==0] = -1 # for convenience with formulas
y_test[y_test==0] = -1

# %%
clf = SVM(epochs=3, lr=1, batch_size=20, verbose=True)
clf.fit(X, y)
pred = clf.predict(X_test)
print("Test accuracy: ", accuracy_score(y_test, pred))
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);
# Out:
# Epoch 0, Loss: 0.3562434911727905
# Epoch 1, Loss: 0.41396439969539645
# Epoch 2, Loss: 0.33505588173866274
# Test accuracy:  0.68

# %%
clf = SVM(epochs=100, lr=0.1, batch_size=20, verbose=True, kernel_function=SVM.rbf)
clf.fit(X, y)
pred = clf.predict(X_test)
print("Test accuracy: ", accuracy_score(y_test, pred))
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);
# Out:
# Epoch 0, Loss: 0.2562751740217209
# Epoch 1, Loss: 0.21933702230453492
# Epoch 2, Loss: 0.22089640498161317
# Epoch 3, Loss: 0.1975347727537155
# Epoch 4, Loss: 0.25487013161182404
# Epoch 5, Loss: 0.2124924212694168
# Epoch 6, Loss: 0.1972496062517166
# Epoch 7, Loss: 0.20445772856473923
# Epoch 8, Loss: 0.21422670185565948
# Epoch 9, Loss: 0.21088624596595765
# Epoch 10, Loss: 0.16195370703935624
# Epoch 11, Loss: 0.21954734325408937
# Epoch 12, Loss: 0.22943986654281617
# Epoch 13, Loss: 0.19083717316389084
# Epoch 14, Loss: 0.147268670797348
# Epoch 15, Loss: 0.22036342769861222
# Epoch 16, Loss: 0.12445772662758828
# Epoch 17, Loss: 0.08507758378982544
# Epoch 18, Loss: 0.12713681012392045
# Epoch 19, Loss: 0.10352142006158829
# Epoch 20, Loss: 0.17846736460924148
# Epoch 21, Loss: 0.18775844648480416
# Epoch 22, Loss: 0.14216538220643998
# Epoch 23, Loss: 0.1268720842897892
# Epoch 24, Loss: 0.10573413074016572
# Epoch 25, Loss: 0.10801236629486084
# Epoch 26, Loss: 0.09491867981851101
# Epoch 27, Loss: 0.0996491277590394
# Epoch 28, Loss: 0.08463879395276308
# Epoch 29, Loss: 0.11556201092898846
# Epoch 30, Loss: 0.06089381976053119
# Epoch 31, Loss: 0.12130856961011886
# Epoch 32, Loss: 0.1286913238465786
# Epoch 33, Loss: 0.11323452573269606
# Epoch 34, Loss: 0.03155806431313977
# Epoch 35, Loss: 0.015975053911097346
# Epoch 36, Loss: 0.00983218377805315
# Epoch 37, Loss: 0.028620221035089342
# Epoch 38, Loss: 0.02221954830456525
# Epoch 39, Loss: 0.009684560258756391
# Epoch 40, Loss: 0.029154378041857852
# Epoch 41, Loss: 0.0027709884016076103
# Epoch 42, Loss: 0.002108710276661441
# Epoch 43, Loss: 0.005543736016261391
# Epoch 44, Loss: 0.05571735268458724
# Epoch 45, Loss: 0.03638557712547481
# Epoch 46, Loss: 0.001962599577382207
# Epoch 47, Loss: 0.0038370335940271618
# Epoch 48, Loss: 0.014355625052121467
# Epoch 49, Loss: 0.021866456209681927
# Epoch 50, Loss: 0.04590221466496587
# Epoch 51, Loss: 0.036048085521906616
# Epoch 52, Loss: 0.002115786977810785
# Epoch 53, Loss: 0.01161100883036852
# Epoch 54, Loss: 0.028051987942308187
# Epoch 55, Loss: 0.002779416588600725
# Epoch 56, Loss: 0.007498971064342186
# Epoch 57, Loss: 0.0012655813014134764
# Epoch 58, Loss: 0.0017585789493750781
# Epoch 59, Loss: 0.0005877070245333016
# Epoch 60, Loss: 0.0016854784451425075
# Epoch 61, Loss: 0.0012179476529126988
# Epoch 62, Loss: 0.0008004772040294484
# Epoch 63, Loss: 0.0007639422459760681
# Epoch 64, Loss: 0.0008080197556409984
# Epoch 65, Loss: 0.00048448374145664274
# Epoch 66, Loss: 0.0010223536053672432
# Epoch 67, Loss: 0.00035531584289856256
# Epoch 68, Loss: 0.0022445912414696067
# Epoch 69, Loss: 0.0010113717697095125
# Epoch 70, Loss: 0.0003009469714015722
# Epoch 71, Loss: 0.001103415703983046
# Epoch 72, Loss: 0.0006611803721170873
# Epoch 73, Loss: 0.0008921724918764084
# Epoch 74, Loss: 0.0019294257916044443
# Epoch 75, Loss: 0.0019375440489966423
# Epoch 76, Loss: 0.0008414601441472768
# Epoch 77, Loss: 0.0006368611153448001
# Epoch 78, Loss: 0.0010364202287746593
# Epoch 79, Loss: 0.00034773919323924927
# Epoch 80, Loss: 0.001781260027200915
# Epoch 81, Loss: 0.0006940941733773798
# Epoch 82, Loss: 0.0008032226993236691
# Epoch 83, Loss: 0.0009585913328919559
# Epoch 84, Loss: 0.000758954806951806
# Epoch 85, Loss: 0.010809736745432019
# Epoch 86, Loss: 0.04076720736920834
# Epoch 87, Loss: 0.0008302491187350824
# Epoch 88, Loss: 0.0010422529187053442
# Epoch 89, Loss: 0.0002836117404513061
# Epoch 90, Loss: 0.0022119322791695597
# Epoch 91, Loss: 0.0006393416348146275
# Epoch 92, Loss: 0.003126800124300644
# Epoch 93, Loss: 0.00028699280810542407
# Epoch 94, Loss: 0.0002868489071261138
# Epoch 95, Loss: 0.00028670586470980197
# Epoch 96, Loss: 0.0002865550282876939
# Epoch 97, Loss: 0.00028639660158660265
# Epoch 98, Loss: 0.00028623247344512494
# Epoch 99, Loss: 0.00028610234730876984
# Test accuracy:  1.0

# %%
assert accuracy_score(y_test, pred) > 0.95

# %% [markdown]
# ## Our model with rbf kernel can learn this dataset too.
